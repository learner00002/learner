# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salesdata = pd.read_csv(r'C:\Users\HP\Downloads\Sales_add (1).csv')

# %%
salesdata.head()
# Out:
#      Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0  Month-1  Region - A  Manager - A                          132921
# 1  Month-2  Region - A  Manager - C                          149559
# 2  Month-3  Region - B  Manager - A                          146278
# 3  Month-4  Region - B  Manager - B                          152167
# 4  Month-5  Region - C  Manager - B                          159525
#
#    Sales_After_digital_add(in $)
# 0                         270390
# 1                         223334
# 2                         244243
# 3                         231808
# 4                         258402

# %%
salesdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Month                           22 non-null     object
#  1   Region                          22 non-null     object
#  2   Manager                         22 non-null     object
#  3   Sales_before_digital_add(in $)  22 non-null     int64
#  4   Sales_After_digital_add(in $)   22 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 1008.0+ bytes

# %%
salesdata.describe()
# Out:
#        Sales_before_digital_add(in $)  Sales_After_digital_add(in $)
# count                       22.000000                      22.000000
# mean                    149239.954545                  231123.727273
# std                      14844.042921                   25556.777061
# min                     130263.000000                  187305.000000
# 25%                     138087.750000                  214960.750000
# 50%                     147444.000000                  229986.500000
# 75%                     157627.500000                  250909.000000
# max                     178939.000000                  276279.000000

# %%
salesregion = salesdata.set_index('Region')

# %%
salesregion.plot.bar()
plt.show()

# %% [markdown]
# ### Company to clarify effect of digital marketing on Sales

# %%
from statsmodels.stats.weightstats import ztest

# %%
z_val,p_val = ztest(salesdata['Sales_before_digital_add(in $)'],salesdata['Sales_After_digital_add(in $)'],value=0)

# %%
p_val
# Out:
# 1.3046367348248653e-38

# %%
if p_val<0.05:
    print('Reject Null Hypothesis')
# Out:
# Reject Null Hypothesis

# %%
salesgroup = salesdata.groupby(['Region','Manager'])

# %%
salesgroup.plot(kind = 'bar')
# Out:
# Region      Manager
# Region - A  Manager - A    Axes(0.125,0.11;0.775x0.77)
#             Manager - B    Axes(0.125,0.11;0.775x0.77)
#             Manager - C    Axes(0.125,0.11;0.775x0.77)
# Region - B  Manager - A    Axes(0.125,0.11;0.775x0.77)
#             Manager - B    Axes(0.125,0.11;0.775x0.77)
#             Manager - C    Axes(0.125,0.11;0.775x0.77)
# Region - C  Manager - A    Axes(0.125,0.11;0.775x0.77)
#             Manager - B    Axes(0.125,0.11;0.775x0.77)
#             Manager - C    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
# based on this we got the hypothesis.
